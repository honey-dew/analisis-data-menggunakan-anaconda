# %% [markdown]
# ## Data Wrangling Python

# %% [markdown]
# ### Data Tidying

# %%
import pandas as pd

# %%
storms = pd.read_csv("https://raw.githubusercontent.com/rstudio/EDAWR/master/data-raw/storms.csv")
storms
# Out:
#      storm  wind  pressure        date
# 0  Alberto   110      1007  2000-08-03
# 1     Alex    45      1009  1998-07-27
# 2  Allison    65      1005  1995-06-03
# 3      Ana    40      1013  1997-06-30
# 4   Arlene    50      1010  1999-06-11
# 5   Arthur    45      1010  1996-06-17

# %%
cases = pd.read_csv("https://raw.githubusercontent.com/rstudio/EDAWR/master/data-raw/cases.csv")
cases
# Out:
#   country   2011   2012   2013
# 0      FR   7000   6900   7000
# 1      DE   5800   6000   6200
# 2      US  15000  14000  13000

# %%
pollution = pd.read_csv("https://raw.githubusercontent.com/rstudio/EDAWR/master/data-raw/pollution.csv")
pollution
# Out:
#        city   size  amount
# 0  New York  large      23
# 1  New York  small      14
# 2    London  large      22
# 3    London  small      16
# 4   Beijing  large     121
# 5   Beijing  small      56

# %%
pd.melt(
    cases,
    id_vars = "country",
    value_vars = ["2011", "2012", "2013"]
)
# Out:
#   country variable  value
# 0      FR     2011   7000
# 1      DE     2011   5800
# 2      US     2011  15000
# 3      FR     2012   6900
# 4      DE     2012   6000
# 5      US     2012  14000
# 6      FR     2013   7000
# 7      DE     2013   6200
# 8      US     2013  13000

# %%
tidy_pollution = pd.pivot(data = pollution, index = "city", columns = "size")
tidy_pollution.columns = tidy_pollution.columns.get_level_values(1).to_numpy()
tidy_pollution.reset_index(inplace=True)
tidy_pollution
# Out:
#        city  large  small
# 0   Beijing    121     56
# 1    London     22     16
# 2  New York     23     14

# %% [markdown]
# #### Separate dan Unite

# %% [markdown]
# ##### Separate

# %%
storms_split_date = storms.copy()
storms_split_date[["year", "month", "day"]] = storms_split_date["date"].str.split("-", expand=True)
storms_split_date.drop(columns=["date"], inplace=True)
storms_split_date
# Out:
#      storm  wind  pressure  year month day
# 0  Alberto   110      1007  2000    08  03
# 1     Alex    45      1009  1998    07  27
# 2  Allison    65      1005  1995    06  03
# 3      Ana    40      1013  1997    06  30
# 4   Arlene    50      1010  1999    06  11
# 5   Arthur    45      1010  1996    06  17

# %%
storms_join_date = storms_split_date.copy()
storms_join_date["date"] = storms_join_date["year"] + "-" + storms_join_date["month"] + "-" + storms_join_date["day"]
storms_join_date.drop(columns=["year", "month", "day"], inplace=True)
storms_join_date
# Out:
#      storm  wind  pressure        date
# 0  Alberto   110      1007  2000-08-03
# 1     Alex    45      1009  1998-07-27
# 2  Allison    65      1005  1995-06-03
# 3      Ana    40      1013  1997-06-30
# 4   Arlene    50      1010  1999-06-11
# 5   Arthur    45      1010  1996-06-17

# %%
storms_join_date2 = storms_split_date.copy()
storms_join_date2["date"] = storms_join_date2[["year", "month", "day"]].T.agg("-".join)
storms_join_date2.drop(columns=["year", "month", "day"], inplace=True)
storms_join_date2
# Out:
#      storm  wind  pressure        date
# 0  Alberto   110      1007  2000-08-03
# 1     Alex    45      1009  1998-07-27
# 2  Allison    65      1005  1995-06-03
# 3      Ana    40      1013  1997-06-30
# 4   Arlene    50      1010  1999-06-11
# 5   Arthur    45      1010  1996-06-17

# %% [markdown]
# ### Data Transformation

# %%
flights = pd.read_csv("data/flights.csv")

# %% [markdown]
# #### Filter
#
# - Flight to SFO atau OAK
# - Flight in January
# - Flight delayed more than one hour
# - Flight departed between midnight and 5am (inclusive)

# %%
flights.loc[(flights["dest"] == "SFO") | (flights["dest"] == "OAK")]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 13      2013      1    1     558.0             600       -2.0     923.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 55      2013      1    1     655.0             700       -5.0    1037.0
# 82      2013      1    1     729.0             730       -1.0    1049.0
# 87      2013      1    1     734.0             737       -3.0    1047.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336658  2013      9   30    1938.0            1850       48.0    2248.0
# 336662  2013      9   30    1940.0            1900       40.0    2228.0
# 336679  2013      9   30    2001.0            2000        1.0    2302.0
# 336701  2013      9   30    2023.0            2025       -2.0    2315.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# 26                 931       14.0      UA     303  N532UA    JFK  SFO
# 55                1045       -8.0      DL    1865  N705TW    JFK  SFO
# 82                1115      -26.0      VX      11  N635VA    JFK  SFO
# 87                1113      -26.0      B6     643  N625JB    JFK  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336658            2220       28.0      VX      29  N626VA    JFK  SFO
# 336662            2232       -4.0      DL    1465  N723TW    JFK  SFO
# 336679            2328      -26.0      UA    1651  N35260    EWR  SFO
# 336701            2350      -35.0      B6     915  N712JB    JFK  SFO
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute            time_hour
# 13         361.0      2565     6       0  2013-01-01 06:00:00
# 26         366.0      2586     6       0  2013-01-01 06:00:00
# 55         362.0      2586     7       0  2013-01-01 07:00:00
# 82         356.0      2586     7      30  2013-01-01 07:00:00
# 87         350.0      2586     7      37  2013-01-01 07:00:00
# ...          ...       ...   ...     ...                  ...
# 336658     323.0      2586    18      50  2013-09-30 18:00:00
# 336662     323.0      2586    19       0  2013-09-30 19:00:00
# 336679     323.0      2565    20       0  2013-09-30 20:00:00
# 336701     327.0      2586    20      25  2013-09-30 20:00:00
# 336762     318.0      2565    21      13  2013-09-30 21:00:00
#
# [13643 rows x 19 columns]

# %%
flights.loc[flights["dest"].isin(["SFO", "OAK"])]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 13      2013      1    1     558.0             600       -2.0     923.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 55      2013      1    1     655.0             700       -5.0    1037.0
# 82      2013      1    1     729.0             730       -1.0    1049.0
# 87      2013      1    1     734.0             737       -3.0    1047.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336658  2013      9   30    1938.0            1850       48.0    2248.0
# 336662  2013      9   30    1940.0            1900       40.0    2228.0
# 336679  2013      9   30    2001.0            2000        1.0    2302.0
# 336701  2013      9   30    2023.0            2025       -2.0    2315.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# 26                 931       14.0      UA     303  N532UA    JFK  SFO
# 55                1045       -8.0      DL    1865  N705TW    JFK  SFO
# 82                1115      -26.0      VX      11  N635VA    JFK  SFO
# 87                1113      -26.0      B6     643  N625JB    JFK  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336658            2220       28.0      VX      29  N626VA    JFK  SFO
# 336662            2232       -4.0      DL    1465  N723TW    JFK  SFO
# 336679            2328      -26.0      UA    1651  N35260    EWR  SFO
# 336701            2350      -35.0      B6     915  N712JB    JFK  SFO
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute            time_hour
# 13         361.0      2565     6       0  2013-01-01 06:00:00
# 26         366.0      2586     6       0  2013-01-01 06:00:00
# 55         362.0      2586     7       0  2013-01-01 07:00:00
# 82         356.0      2586     7      30  2013-01-01 07:00:00
# 87         350.0      2586     7      37  2013-01-01 07:00:00
# ...          ...       ...   ...     ...                  ...
# 336658     323.0      2586    18      50  2013-09-30 18:00:00
# 336662     323.0      2586    19       0  2013-09-30 19:00:00
# 336679     323.0      2565    20       0  2013-09-30 20:00:00
# 336701     327.0      2586    20      25  2013-09-30 20:00:00
# 336762     318.0      2565    21      13  2013-09-30 21:00:00
#
# [13643 rows x 19 columns]

# %%
flights.query("dest in ['SFO', 'OAK']")
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 13      2013      1    1     558.0             600       -2.0     923.0
# 26      2013      1    1     611.0             600       11.0     945.0
# 55      2013      1    1     655.0             700       -5.0    1037.0
# 82      2013      1    1     729.0             730       -1.0    1049.0
# 87      2013      1    1     734.0             737       -3.0    1047.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336658  2013      9   30    1938.0            1850       48.0    2248.0
# 336662  2013      9   30    1940.0            1900       40.0    2228.0
# 336679  2013      9   30    2001.0            2000        1.0    2302.0
# 336701  2013      9   30    2023.0            2025       -2.0    2315.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 13                 937      -14.0      UA    1124  N53441    EWR  SFO
# 26                 931       14.0      UA     303  N532UA    JFK  SFO
# 55                1045       -8.0      DL    1865  N705TW    JFK  SFO
# 82                1115      -26.0      VX      11  N635VA    JFK  SFO
# 87                1113      -26.0      B6     643  N625JB    JFK  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 336658            2220       28.0      VX      29  N626VA    JFK  SFO
# 336662            2232       -4.0      DL    1465  N723TW    JFK  SFO
# 336679            2328      -26.0      UA    1651  N35260    EWR  SFO
# 336701            2350      -35.0      B6     915  N712JB    JFK  SFO
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
#
#         air_time  distance  hour  minute            time_hour
# 13         361.0      2565     6       0  2013-01-01 06:00:00
# 26         366.0      2586     6       0  2013-01-01 06:00:00
# 55         362.0      2586     7       0  2013-01-01 07:00:00
# 82         356.0      2586     7      30  2013-01-01 07:00:00
# 87         350.0      2586     7      37  2013-01-01 07:00:00
# ...          ...       ...   ...     ...                  ...
# 336658     323.0      2586    18      50  2013-09-30 18:00:00
# 336662     323.0      2586    19       0  2013-09-30 19:00:00
# 336679     323.0      2565    20       0  2013-09-30 20:00:00
# 336701     327.0      2586    20      25  2013-09-30 20:00:00
# 336762     318.0      2565    21      13  2013-09-30 21:00:00
#
# [13643 rows x 19 columns]

# %%
flights.loc[flights["month"] == 1]
# Out:
#        year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0      2013      1    1     517.0             515        2.0     830.0
# 1      2013      1    1     533.0             529        4.0     850.0
# 2      2013      1    1     542.0             540        2.0     923.0
# 3      2013      1    1     544.0             545       -1.0    1004.0
# 4      2013      1    1     554.0             600       -6.0     812.0
# ...     ...    ...  ...       ...             ...        ...       ...
# 26999  2013      1   31       NaN            1325        NaN       NaN
# 27000  2013      1   31       NaN            1200        NaN       NaN
# 27001  2013      1   31       NaN            1410        NaN       NaN
# 27002  2013      1   31       NaN            1446        NaN       NaN
# 27003  2013      1   31       NaN             625        NaN       NaN
#
#        sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                 819       11.0      UA    1545  N14228    EWR  IAH
# 1                 830       20.0      UA    1714  N24211    LGA  IAH
# 2                 850       33.0      AA    1141  N619AA    JFK  MIA
# 3                1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                 837      -25.0      DL     461  N668DN    LGA  ATL
# ...               ...        ...     ...     ...     ...    ...  ...
# 26999            1505        NaN      MQ    4475  N730MQ    LGA  RDU
# 27000            1430        NaN      MQ    4658  N505MQ    LGA  ATL
# 27001            1555        NaN      MQ    4491  N734MQ    LGA  CLE
# 27002            1757        NaN      UA     337     NaN    LGA  IAH
# 27003             934        NaN      UA    1497     NaN    LGA  IAH
#
#        air_time  distance  hour  minute            time_hour
# 0         227.0      1400     5      15  2013-01-01 05:00:00
# 1         227.0      1416     5      29  2013-01-01 05:00:00
# 2         160.0      1089     5      40  2013-01-01 05:00:00
# 3         183.0      1576     5      45  2013-01-01 05:00:00
# 4         116.0       762     6       0  2013-01-01 06:00:00
# ...         ...       ...   ...     ...                  ...
# 26999       NaN       431    13      25  2013-01-31 13:00:00
# 27000       NaN       762    12       0  2013-01-31 12:00:00
# 27001       NaN       419    14      10  2013-01-31 14:00:00
# 27002       NaN      1416    14      46  2013-01-31 14:00:00
# 27003       NaN      1416     6      25  2013-01-31 06:00:00
#
# [27004 rows x 19 columns]

# %%
flights.query("month == 1")
# Out:
#        year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0      2013      1    1     517.0             515        2.0     830.0
# 1      2013      1    1     533.0             529        4.0     850.0
# 2      2013      1    1     542.0             540        2.0     923.0
# 3      2013      1    1     544.0             545       -1.0    1004.0
# 4      2013      1    1     554.0             600       -6.0     812.0
# ...     ...    ...  ...       ...             ...        ...       ...
# 26999  2013      1   31       NaN            1325        NaN       NaN
# 27000  2013      1   31       NaN            1200        NaN       NaN
# 27001  2013      1   31       NaN            1410        NaN       NaN
# 27002  2013      1   31       NaN            1446        NaN       NaN
# 27003  2013      1   31       NaN             625        NaN       NaN
#
#        sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                 819       11.0      UA    1545  N14228    EWR  IAH
# 1                 830       20.0      UA    1714  N24211    LGA  IAH
# 2                 850       33.0      AA    1141  N619AA    JFK  MIA
# 3                1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                 837      -25.0      DL     461  N668DN    LGA  ATL
# ...               ...        ...     ...     ...     ...    ...  ...
# 26999            1505        NaN      MQ    4475  N730MQ    LGA  RDU
# 27000            1430        NaN      MQ    4658  N505MQ    LGA  ATL
# 27001            1555        NaN      MQ    4491  N734MQ    LGA  CLE
# 27002            1757        NaN      UA     337     NaN    LGA  IAH
# 27003             934        NaN      UA    1497     NaN    LGA  IAH
#
#        air_time  distance  hour  minute            time_hour
# 0         227.0      1400     5      15  2013-01-01 05:00:00
# 1         227.0      1416     5      29  2013-01-01 05:00:00
# 2         160.0      1089     5      40  2013-01-01 05:00:00
# 3         183.0      1576     5      45  2013-01-01 05:00:00
# 4         116.0       762     6       0  2013-01-01 06:00:00
# ...         ...       ...   ...     ...                  ...
# 26999       NaN       431    13      25  2013-01-31 13:00:00
# 27000       NaN       762    12       0  2013-01-31 12:00:00
# 27001       NaN       419    14      10  2013-01-31 14:00:00
# 27002       NaN      1416    14      46  2013-01-31 14:00:00
# 27003       NaN      1416     6      25  2013-01-31 06:00:00
#
# [27004 rows x 19 columns]

# %%
flights.loc[flights["dep_delay"] > 60]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1     811.0             630      101.0    1047.0
# 135     2013      1    1     826.0             715       71.0    1136.0
# 151     2013      1    1     848.0            1835      853.0    1001.0
# 218     2013      1    1     957.0             733      144.0    1056.0
# 268     2013      1    1    1114.0             900      134.0    1447.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336742  2013      9   30    2119.0            2005       74.0    2310.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336760  2013      9   30    2211.0            2059       72.0    2339.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 119                830      137.0      MQ    4576  N531MQ    LGA  CLT
# 135               1045       51.0      AA     443  N3GVAA    JFK  MIA
# 151               1950      851.0      MQ    3944  N942MQ    JFK  BWI
# 218                853      123.0      UA     856  N534UA    EWR  BOS
# 268               1222      145.0      UA    1086  N76502    LGA  IAH
# ...                ...        ...     ...     ...     ...    ...  ...
# 336742            2212       58.0      EV    4321  N17984    EWR  MCI
# 336757            2030      194.0      9E    3320  N906XJ    JFK  BUF
# 336760            2242       57.0      EV    4672  N12145    EWR  STL
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
# 336763            2249      130.0      B6    1083  N804JB    JFK  MCO
#
#         air_time  distance  hour  minute            time_hour
# 119        118.0       544     6      30  2013-01-01 06:00:00
# 135        160.0      1089     7      15  2013-01-01 07:00:00
# 151         41.0       184    18      35  2013-01-01 18:00:00
# 218         37.0       200     7      33  2013-01-01 07:00:00
# 268        248.0      1416     9       0  2013-01-01 09:00:00
# ...          ...       ...   ...     ...                  ...
# 336742     147.0      1092    20       5  2013-09-30 20:00:00
# 336757      50.0       301    18      45  2013-09-30 18:00:00
# 336760     120.0       872    20      59  2013-09-30 20:00:00
# 336762     318.0      2565    21      13  2013-09-30 21:00:00
# 336763     123.0       944    20       1  2013-09-30 20:00:00
#
# [26581 rows x 19 columns]

# %%
flights.query("dep_delay > 60")
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1     811.0             630      101.0    1047.0
# 135     2013      1    1     826.0             715       71.0    1136.0
# 151     2013      1    1     848.0            1835      853.0    1001.0
# 218     2013      1    1     957.0             733      144.0    1056.0
# 268     2013      1    1    1114.0             900      134.0    1447.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336742  2013      9   30    2119.0            2005       74.0    2310.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336760  2013      9   30    2211.0            2059       72.0    2339.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 119                830      137.0      MQ    4576  N531MQ    LGA  CLT
# 135               1045       51.0      AA     443  N3GVAA    JFK  MIA
# 151               1950      851.0      MQ    3944  N942MQ    JFK  BWI
# 218                853      123.0      UA     856  N534UA    EWR  BOS
# 268               1222      145.0      UA    1086  N76502    LGA  IAH
# ...                ...        ...     ...     ...     ...    ...  ...
# 336742            2212       58.0      EV    4321  N17984    EWR  MCI
# 336757            2030      194.0      9E    3320  N906XJ    JFK  BUF
# 336760            2242       57.0      EV    4672  N12145    EWR  STL
# 336762              30       42.0      UA     471  N578UA    EWR  SFO
# 336763            2249      130.0      B6    1083  N804JB    JFK  MCO
#
#         air_time  distance  hour  minute            time_hour
# 119        118.0       544     6      30  2013-01-01 06:00:00
# 135        160.0      1089     7      15  2013-01-01 07:00:00
# 151         41.0       184    18      35  2013-01-01 18:00:00
# 218         37.0       200     7      33  2013-01-01 07:00:00
# 268        248.0      1416     9       0  2013-01-01 09:00:00
# ...          ...       ...   ...     ...                  ...
# 336742     147.0      1092    20       5  2013-09-30 20:00:00
# 336757      50.0       301    18      45  2013-09-30 18:00:00
# 336760     120.0       872    20      59  2013-09-30 20:00:00
# 336762     318.0      2565    21      13  2013-09-30 21:00:00
# 336763     123.0       944    20       1  2013-09-30 20:00:00
#
# [26581 rows x 19 columns]

# %%
flights.loc[(flights["hour"] >= 0) & (flights["hour"] <= 5)]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 335784  2013      9   30     516.0             517       -1.0     734.0
# 335785  2013      9   30     540.0             545       -5.0     821.0
# 335786  2013      9   30     540.0             545       -5.0     918.0
# 335787  2013      9   30     549.0             550       -1.0     911.0
# 335788  2013      9   30     549.0             545        4.0     825.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 5                  728       12.0      UA    1696  N39463    EWR  ORD
# ...                ...        ...     ...     ...     ...    ...  ...
# 335784             757      -23.0      UA     252  N571UA    EWR  IAH
# 335785             855      -34.0      AA    2243  N622AA    JFK  MIA
# 335786             933      -15.0      B6    1403  N510JB    JFK  SJU
# 335787             932      -21.0      B6     939  N552JB    JFK  BQN
# 335788             827       -2.0      UA    1714  N21723    LGA  IAH
#
#         air_time  distance  hour  minute            time_hour
# 0          227.0      1400     5      15  2013-01-01 05:00:00
# 1          227.0      1416     5      29  2013-01-01 05:00:00
# 2          160.0      1089     5      40  2013-01-01 05:00:00
# 3          183.0      1576     5      45  2013-01-01 05:00:00
# 5          150.0       719     5      58  2013-01-01 05:00:00
# ...          ...       ...   ...     ...                  ...
# 335784     181.0      1400     5      17  2013-09-30 05:00:00
# 335785     143.0      1089     5      45  2013-09-30 05:00:00
# 335786     194.0      1598     5      45  2013-09-30 05:00:00
# 335787     185.0      1576     5      50  2013-09-30 05:00:00
# 335788     190.0      1416     5      45  2013-09-30 05:00:00
#
# [1954 rows x 19 columns]

# %%
flights.query("hour >= 0 and hour <= 5")
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 335784  2013      9   30     516.0             517       -1.0     734.0
# 335785  2013      9   30     540.0             545       -5.0     821.0
# 335786  2013      9   30     540.0             545       -5.0     918.0
# 335787  2013      9   30     549.0             550       -1.0     911.0
# 335788  2013      9   30     549.0             545        4.0     825.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 5                  728       12.0      UA    1696  N39463    EWR  ORD
# ...                ...        ...     ...     ...     ...    ...  ...
# 335784             757      -23.0      UA     252  N571UA    EWR  IAH
# 335785             855      -34.0      AA    2243  N622AA    JFK  MIA
# 335786             933      -15.0      B6    1403  N510JB    JFK  SJU
# 335787             932      -21.0      B6     939  N552JB    JFK  BQN
# 335788             827       -2.0      UA    1714  N21723    LGA  IAH
#
#         air_time  distance  hour  minute            time_hour
# 0          227.0      1400     5      15  2013-01-01 05:00:00
# 1          227.0      1416     5      29  2013-01-01 05:00:00
# 2          160.0      1089     5      40  2013-01-01 05:00:00
# 3          183.0      1576     5      45  2013-01-01 05:00:00
# 5          150.0       719     5      58  2013-01-01 05:00:00
# ...          ...       ...   ...     ...                  ...
# 335784     181.0      1400     5      17  2013-09-30 05:00:00
# 335785     143.0      1089     5      45  2013-09-30 05:00:00
# 335786     194.0      1598     5      45  2013-09-30 05:00:00
# 335787     185.0      1576     5      50  2013-09-30 05:00:00
# 335788     190.0      1416     5      45  2013-09-30 05:00:00
#
# [1954 rows x 19 columns]

# %%
flights[["dep_delay", "arr_delay", "dest"]]
# Out:
#         dep_delay  arr_delay dest
# 0             2.0       11.0  IAH
# 1             4.0       20.0  IAH
# 2             2.0       33.0  MIA
# 3            -1.0      -18.0  BQN
# 4            -6.0      -25.0  ATL
# ...           ...        ...  ...
# 336771        NaN        NaN  DCA
# 336772        NaN        NaN  SYR
# 336773        NaN        NaN  BNA
# 336774        NaN        NaN  CLE
# 336775        NaN        NaN  RDU
#
# [336776 rows x 3 columns]

# %%
flights.filter(like = "time")
# Out:
#         dep_time  sched_dep_time  arr_time  sched_arr_time  air_time  \
# 0          517.0             515     830.0             819     227.0
# 1          533.0             529     850.0             830     227.0
# 2          542.0             540     923.0             850     160.0
# 3          544.0             545    1004.0            1022     183.0
# 4          554.0             600     812.0             837     116.0
# ...          ...             ...       ...             ...       ...
# 336771       NaN            1455       NaN            1634       NaN
# 336772       NaN            2200       NaN            2312       NaN
# 336773       NaN            1210       NaN            1330       NaN
# 336774       NaN            1159       NaN            1344       NaN
# 336775       NaN             840       NaN            1020       NaN
#
#                   time_hour
# 0       2013-01-01 05:00:00
# 1       2013-01-01 05:00:00
# 2       2013-01-01 05:00:00
# 3       2013-01-01 05:00:00
# 4       2013-01-01 06:00:00
# ...                     ...
# 336771  2013-09-30 14:00:00
# 336772  2013-09-30 22:00:00
# 336773  2013-09-30 12:00:00
# 336774  2013-09-30 11:00:00
# 336775  2013-09-30 08:00:00
#
# [336776 rows x 6 columns]

# %%
flights[flights.columns[:5]]
# Out:
#         year  month  day  dep_time  sched_dep_time
# 0       2013      1    1     517.0             515
# 1       2013      1    1     533.0             529
# 2       2013      1    1     542.0             540
# 3       2013      1    1     544.0             545
# 4       2013      1    1     554.0             600
# ...      ...    ...  ...       ...             ...
# 336771  2013      9   30       NaN            1455
# 336772  2013      9   30       NaN            2200
# 336773  2013      9   30       NaN            1210
# 336774  2013      9   30       NaN            1159
# 336775  2013      9   30       NaN             840
#
# [336776 rows x 5 columns]

# %%
flights.iloc[:, flights.columns.get_loc("origin"):flights.columns.get_loc("time_hour")+1]
# Out:
#        origin dest  air_time  distance  hour  minute            time_hour
# 0         EWR  IAH     227.0      1400     5      15  2013-01-01 05:00:00
# 1         LGA  IAH     227.0      1416     5      29  2013-01-01 05:00:00
# 2         JFK  MIA     160.0      1089     5      40  2013-01-01 05:00:00
# 3         JFK  BQN     183.0      1576     5      45  2013-01-01 05:00:00
# 4         LGA  ATL     116.0       762     6       0  2013-01-01 06:00:00
# ...       ...  ...       ...       ...   ...     ...                  ...
# 336771    JFK  DCA       NaN       213    14      55  2013-09-30 14:00:00
# 336772    LGA  SYR       NaN       198    22       0  2013-09-30 22:00:00
# 336773    LGA  BNA       NaN       764    12      10  2013-09-30 12:00:00
# 336774    LGA  CLE       NaN       419    11      59  2013-09-30 11:00:00
# 336775    LGA  RDU       NaN       431     8      40  2013-09-30 08:00:00
#
# [336776 rows x 7 columns]

# %% [markdown]
# #### Arrange atau Sort

# %%
flights.sort_values(by = ["time_hour", "dest"])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 15      2013      1    1     559.0             559        0.0     702.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 110520  2013     12   31      13.0            2359       14.0     439.0
# 111279  2013     12   31    2356.0            2359       -3.0     436.0
# 110521  2013     12   31      18.0            2359       19.0     449.0
# 111276  2013     12   31    2328.0            2330       -2.0     412.0
# 111278  2013     12   31    2355.0            2359       -4.0     430.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 15                 706       -4.0      B6    1806  N708JB    JFK  BOS
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# 110520             437        2.0      B6     839  N566JB    JFK  BQN
# 111279             445       -9.0      B6     745  N665JB    JFK  PSE
# 110521             444        5.0      DL     412  N713TW    JFK  SJU
# 111276             409        3.0      B6    1389  N651JB    EWR  SJU
# 111278             440      -10.0      B6    1503  N509JB    JFK  SJU
#
#         air_time  distance  hour  minute            time_hour
# 15          44.0       187     5      59  2013-01-01 05:00:00
# 3          183.0      1576     5      45  2013-01-01 05:00:00
# 0          227.0      1400     5      15  2013-01-01 05:00:00
# 1          227.0      1416     5      29  2013-01-01 05:00:00
# 2          160.0      1089     5      40  2013-01-01 05:00:00
# ...          ...       ...   ...     ...                  ...
# 110520     189.0      1576    23      59  2013-12-31 23:00:00
# 111279     200.0      1617    23      59  2013-12-31 23:00:00
# 110521     192.0      1598    23      59  2013-12-31 23:00:00
# 111276     198.0      1608    23      30  2013-12-31 23:00:00
# 111278     195.0      1598    23      59  2013-12-31 23:00:00
#
# [336776 rows x 19 columns]

# %%
flights.sort_values(by = "dep_delay", ascending = False)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 7072    2013      1    9     641.0             900     1301.0    1242.0
# 235778  2013      6   15    1432.0            1935     1137.0    1607.0
# 8239    2013      1   10    1121.0            1635     1126.0    1239.0
# 327043  2013      9   20    1139.0            1845     1014.0    1457.0
# 270376  2013      7   22     845.0            1600     1005.0    1044.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 7072              1530     1272.0      HA      51  N384HA    JFK  HNL
# 235778            2120     1127.0      MQ    3535  N504MQ    JFK  CMH
# 8239              1810     1109.0      MQ    3695  N517MQ    EWR  ORD
# 327043            2210     1007.0      AA     177  N338AA    JFK  SFO
# 270376            1815      989.0      MQ    3075  N665MQ    JFK  CVG
# ...                ...        ...     ...     ...     ...    ...  ...
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour
# 7072       640.0      4983     9       0  2013-01-09 09:00:00
# 235778      74.0       483    19      35  2013-06-15 19:00:00
# 8239       111.0       719    16      35  2013-01-10 16:00:00
# 327043     354.0      2586    18      45  2013-09-20 18:00:00
# 270376      96.0       589    16       0  2013-07-22 16:00:00
# ...          ...       ...   ...     ...                  ...
# 336771       NaN       213    14      55  2013-09-30 14:00:00
# 336772       NaN       198    22       0  2013-09-30 22:00:00
# 336773       NaN       764    12      10  2013-09-30 12:00:00
# 336774       NaN       419    11      59  2013-09-30 11:00:00
# 336775       NaN       431     8      40  2013-09-30 08:00:00
#
# [336776 rows x 19 columns]

# %% [markdown]
# #### Add New Column atau Mutate

# %%
flights.assign(dep_delay_hour = flights["dep_delay"] / 60)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute            time_hour  dep_delay_hour
# 0          227.0      1400     5      15  2013-01-01 05:00:00        0.033333
# 1          227.0      1416     5      29  2013-01-01 05:00:00        0.066667
# 2          160.0      1089     5      40  2013-01-01 05:00:00        0.033333
# 3          183.0      1576     5      45  2013-01-01 05:00:00       -0.016667
# 4          116.0       762     6       0  2013-01-01 06:00:00       -0.100000
# ...          ...       ...   ...     ...                  ...             ...
# 336771       NaN       213    14      55  2013-09-30 14:00:00             NaN
# 336772       NaN       198    22       0  2013-09-30 22:00:00             NaN
# 336773       NaN       764    12      10  2013-09-30 12:00:00             NaN
# 336774       NaN       419    11      59  2013-09-30 11:00:00             NaN
# 336775       NaN       431     8      40  2013-09-30 08:00:00             NaN
#
# [336776 rows x 20 columns]

# %% [markdown]
# #### Group

# %%
flights.groupby("month")[["year"]].count().reset_index().rename(columns={"year": "count"})
# Out:
#     month  count
# 0       1  27004
# 1       2  24951
# 2       3  28834
# 3       4  28330
# 4       5  28796
# 5       6  28243
# 6       7  29425
# 7       8  29327
# 8       9  27574
# 9      10  28889
# 10     11  27268
# 11     12  28135

# %%
flights.groupby("month").count().reset_index()[["month", "year"]].rename(columns={"year": "count"})
# Out:
#     month  count
# 0       1  27004
# 1       2  24951
# 2       3  28834
# 3       4  28330
# 4       5  28796
# 5       6  28243
# 6       7  29425
# 7       8  29327
# 8       9  27574
# 9      10  28889
# 10     11  27268
# 11     12  28135

# %%
flights.groupby("dest")["year"].count().reset_index().rename(columns={"dest": "count"})
# Out:
#     count   year
# 0     ABQ    254
# 1     ACK    265
# 2     ALB    439
# 3     ANC      8
# 4     ATL  17215
# ..    ...    ...
# 100   TPA   7466
# 101   TUL    315
# 102   TVC    101
# 103   TYS    631
# 104   XNA   1036
#
# [105 rows x 2 columns]

# %%
flights.groupby("dest").count().reset_index()[["dest", "year"]].rename(columns={"year": "count"})
# Out:
#     dest  count
# 0    ABQ    254
# 1    ACK    265
# 2    ALB    439
# 3    ANC      8
# 4    ATL  17215
# ..   ...    ...
# 100  TPA   7466
# 101  TUL    315
# 102  TVC    101
# 103  TYS    631
# 104  XNA   1036
#
# [105 rows x 2 columns]

# %%
flights.groupby("month")["dep_delay"].sum().reset_index().rename(columns={"dep_delay": "total_dep_delay"})
# Out:
#     month  total_dep_delay
# 0       1         265801.0
# 1       2         256251.0
# 2       3         370001.0
# 3       4         385554.0
# 4       5         366658.0
# 5       6         567729.0
# 6       7         618916.0
# 7       8         363715.0
# 8       9         182327.0
# 9      10         178909.0
# 10     11         146945.0
# 11     12         449394.0

# %%
flights.groupby("month").sum("dep_delay").reset_index()[["month", "dep_delay"]].rename(columns={"dep_delay": "total_dep_delay"})
# Out:
#     month  total_dep_delay
# 0       1         265801.0
# 1       2         256251.0
# 2       3         370001.0
# 3       4         385554.0
# 4       5         366658.0
# 5       6         567729.0
# 6       7         618916.0
# 7       8         363715.0
# 8       9         182327.0
# 9      10         178909.0
# 10     11         146945.0
# 11     12         449394.0

# %%
flights.groupby("month").agg({"year": "count", "dep_delay": "sum"}).reset_index()\
    .rename(columns={"year":"count","dep_delay": "total_dep_delay"})
# Out:
#     month  count  total_dep_delay
# 0       1  27004         265801.0
# 1       2  24951         256251.0
# 2       3  28834         370001.0
# 3       4  28330         385554.0
# 4       5  28796         366658.0
# 5       6  28243         567729.0
# 6       7  29425         618916.0
# 7       8  29327         363715.0
# 8       9  27574         182327.0
# 9      10  28889         178909.0
# 10     11  27268         146945.0
# 11     12  28135         449394.0

# %%
most_5_del = flights.copy()
most_5_del = most_5_del.groupby(["month", "carrier"]).agg({"dep_delay": "sum"}).reset_index()
most_5_del["overall_rank"] = most_5_del["dep_delay"].rank(method="dense", ascending=False)
most_5_del["group_rank"] = most_5_del.groupby("month")["dep_delay"].rank(method="dense", ascending=False)
most_5_del.loc[most_5_del["group_rank"] <= 5].sort_values(by=["month", "group_rank"])
# Out:
#      month carrier  dep_delay  overall_rank  group_rank
# 5        1      EV    96649.0           9.0         1.0
# 3        1      B6    41942.0          33.0         2.0
# 11       1      UA    38342.0          38.0         3.0
# 0        1      9E    25290.0          59.0         4.0
# 1        1      AA    18960.0          70.0         5.0
# 21       2      EV    76580.0          17.0         1.0
# 19       2      B6    54403.0          26.0         2.0
# 26       2      UA    32125.0          44.0         3.0
# 16       2      9E    22306.0          63.0         4.0
# 17       2      AA    19906.0          68.0         5.0
# 36       3      EV   114807.0           3.0         1.0
# 34       3      B6    67686.0          21.0         2.0
# 41       3      UA    57583.0          25.0         3.0
# 35       3      DL    41035.0          35.0         4.0
# 32       3      AA    23891.0          60.0         5.0
# 51       4      EV    98925.0           8.0         1.0
# 56       4      UA    68149.0          19.0         2.0
# 49       4      B6    67758.0          20.0         3.0
# 50       4      DL    33393.0          43.0         4.0
# 47       4      AA    31147.0          47.0         5.0
# 66       5      EV    92832.0          11.0         1.0
# 71       5      UA    60194.0          24.0         2.0
# 64       5      B6    44424.0          27.0         3.0
# 65       5      DL    39705.0          36.0         4.0
# 61       5      9E    31469.0          46.0         5.0
# 81       6      EV   104690.0           5.0         1.0
# 87       6      UA    99503.0           7.0         2.0
# 79       6      B6    93233.0          10.0         3.0
# 80       6      DL    76630.0          16.0         4.0
# 85       6      MQ    41643.0          34.0         5.0
# 95       7      B6   122619.0           1.0         1.0
# 97       7      EV   115057.0           2.0         2.0
# 102      7      UA   100526.0           6.0         3.0
# 96       7      DL    86466.0          12.0         4.0
# 101      7      MQ    44229.0          28.0         5.0
# 110      8      B6    77562.0          15.0         1.0
# 112      8      EV    70804.0          18.0         2.0
# 118      8      UA    63439.0          23.0         3.0
# 111      8      DL    42470.0          32.0         4.0
# 107      8      9E    23835.0          61.0         5.0
# 128      9      EV    37664.0          39.0         1.0
# 134      9      UA    32063.0          45.0         2.0
# 126      9      B6    28388.0          54.0         3.0
# 127      9      DL    21408.0          65.0         4.0
# 124      9      AA    14714.0          81.0         5.0
# 144     10      EV    64675.0          22.0         1.0
# 149     10      UA    33491.0          42.0         2.0
# 139     10      9E    15327.0          79.0         3.0
# 143     10      DL    13981.0          86.0         4.0
# 152     10      WN    13569.0          88.0         5.0
# 159     11      EV    43135.0          30.0         1.0
# 165     11      UA    30829.0          49.0         2.0
# 157     11      B6    15075.0          80.0         3.0
# 154     11      9E    11914.0          90.0         4.0
# 168     11      WN    11316.0          92.0         5.0
# 175     12      EV   109011.0           4.0         1.0
# 180     12      UA    85654.0          13.0         2.0
# 173     12      B6    79411.0          14.0         3.0
# 174     12      DL    43981.0          29.0         4.0
# 170     12      9E    30542.0          51.0         5.0
